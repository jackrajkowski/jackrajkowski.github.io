# %% [markdown]
# # Introduction to Neural Networks: Bank Churn prediction

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# Businesses like banks which provide service have to worry about problem of 'Customer Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on improvement of service, keeping in mind these priorities.

# %% [markdown]
# ### Objective

# %% [markdown]
# As a Data scientist with the bank, I need to  build a neural network based classifier that can determine whether a customer will leave the bank  or not in the next 6 months.

# %% [markdown]
# ### Data Dictionary:

# %% [markdown]
# * CustomerId: Unique ID which is assigned to each customer
#
# * Surname: Last name of the customer
#
# * CreditScore: It defines the credit history of the customer.
#
# * Geography: A customer’s location
#
# * Gender: It defines the Gender of the customer
#
# * Age: Age of the customer
#
# * Tenure: Number of years for which the customer has been with the bank
#
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
#
# * Balance: Account balance
#
# * HasCrCard: It is a categorical variable which decides whether the customer has credit card or not.
#
# * EstimatedSalary: Estimated salary
#
# * isActiveMember: Is is a categorical variable which decides whether the customer is active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions etc )
#
# * Exited : whether or not the customer left the bank within six month. It can take two values
# ** 0=No ( Customer did not leave the bank )
# ** 1=Yes ( Customer left the bank )

# %% [markdown]
# ## Importing necessary libraries

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.15.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? Y
#   Successfully uninstalled tensorflow-2.15.0

# %%
# !pip install tensorflow==2.9.1
# Out:
# Collecting tensorflow==2.9.1
#   Downloading tensorflow-2.9.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.6.3)
# Collecting flatbuffers<2,>=1.12 (from tensorflow==2.9.1)
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.9.1)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.60.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (3.9.0)
# Collecting keras<2.10.0,>=2.9.0rc0 (from tensorflow==2.9.1)
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 55.0 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.9.1)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (23.2)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.9.1)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.16.0)
# Collecting tensorboard<2.10,>=2.9 (from tensorflow==2.9.1)
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 55.3 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (0.35.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0 (from tensorflow==2.9.1)
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.9.1) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.9.1) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.10,>=2.9->tensorflow==2.9.1)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9.1)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 49.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.10,>=2.9->tensorflow==2.9.1)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow==2.9.1) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, flatbuffers, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, gast, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.15.0
#     Uninstalling keras-2.15.0:
#       Successfully uninstalled keras-2.15.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.15.0
#     Uninstalling tensorflow-estimator-2.15.0:
#       Successfully uninstalled tensorflow-estimator-2.15.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.2.0
#     Uninstalling google-auth-oauthlib-1.2.0:
#       Successfully uninstalled google-auth-oauthlib-1.2.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.15.1
#     Uninstalling tensorboard-2.15.1:
#       Successfully uninstalled tensorboard-2.15.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-gbq 0.19.2 requires google-auth-oauthlib>=0.7.0, but you have google-auth-oauthlib 0.4.6 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed flatbuffers-1.12 gast-0.4.0 google-auth-oauthlib-0.4.6 keras-2.9.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np
# Library to split data
from sklearn.model_selection import train_test_split
# Library to encode the variables
from sklearn import preprocessing
# To plot confusion matrix
from sklearn.metrics import confusion_matrix
# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# library to import to standardize the data
from sklearn.preprocessing import StandardScaler
#To import different metrics
from sklearn import metrics
from tensorflow.keras import backend
# Library to avoid the warnings
import warnings
warnings.filterwarnings("ignore")
# importing different functions to build models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import tensorflow as tf
# importing GridSearch CV
from sklearn.model_selection import GridSearchCV
# importing roc_curve to plot
from sklearn.metrics import roc_curve
from matplotlib import pyplot
# importing SMOTE
from imblearn.over_sampling import SMOTE
# importing metrics
from sklearn import metrics
import random
#Importing classback API
from keras import callbacks

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Loading the dataset

# %%
data = pd.read_csv('/content/drive/MyDrive/Python Course/Churn.csv')
ds = data.copy()

# %% [markdown]
# ## Data Overview

# %%
ds.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
ds.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
ds.shape
# Out:
# (10000, 14)

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
ds.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
ds.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
round(ds.isnull().sum() / ds.isnull().count() * 100, 2)
# Out:
# RowNumber          0.0
# CustomerId         0.0
# Surname            0.0
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
ds = ds.drop(['CustomerId', 'RowNumber', 'Surname'], axis = 1)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %% [markdown]
# **Questions**:
#
# 1. What is the distribution of the credit score of customers? Are there any noticeable patterns or outliers in the distribution?
# 2. How many active members are there with the bank?
# 3. How are the different customer attributes correlated to each other?
# 4. Who is churning more when compared to males and females?
# 5. Customers from which geographical part are churning more?

# %% [markdown]
# **Univariate Analysis**

# %%
def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
histogram_boxplot(ds,'CreditScore')

# %%
histogram_boxplot(ds,'Age')

# %%
histogram_boxplot(ds,'Balance')

# %%
histogram_boxplot(ds,'EstimatedSalary')

# %%
labeled_barplot(ds, "Exited", perc=True)

# %%
labeled_barplot(ds, "Geography", perc=True)

# %%
labeled_barplot(ds, "Gender", perc=True)

# %%
labeled_barplot(ds, "Tenure", perc=True)

# %%
labeled_barplot(ds, "NumOfProducts", perc=True)

# %%
labeled_barplot(ds, "HasCrCard", perc=True)

# %%
labeled_barplot(ds, "IsActiveMember", perc=True)

# %% [markdown]
# **Bivariate Analysis**

# %%
def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(ds.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")

# %%
stacked_barplot(ds, "Geography", "Exited" )
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(ds, "Gender", "Exited" )
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(ds, "HasCrCard", "Exited" )
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945
# ------------------------------------------------------------------------------------------------------------------------

# %%
stacked_barplot(ds, "IsActiveMember", "Exited" )
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151
# ------------------------------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='CreditScore',x='Exited',data=ds)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Age',x='Exited',data=ds)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Tenure',x='Exited',data=ds)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Balance',x='Exited',data=ds)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='NumOfProducts',x='Exited',data=ds)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='EstimatedSalary',x='Exited',data=ds)
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# * Missing value treatment
# * Feature engineering (if needed)
# * Outlier detection and treatment (if needed)
# * Preparing data for modeling
# * Any other preprocessing steps (if needed)

# %%
X = ds.drop(['Exited'],axis=1)
Y = ds[['Exited']]

# %%
X_large, X_test, y_large, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42,stratify=Y,shuffle = True)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_large,y_large, test_size = 0.2, random_state = 42,stratify=y_large, shuffle = True)

# %%
X_train = pd.get_dummies(X_train, columns=["Geography","Gender"],drop_first=True)
X_test = pd.get_dummies(X_test, columns=["Geography","Gender"],drop_first=True)
X_val = pd.get_dummies(X_val, columns=["Geography","Gender"],drop_first=True)

# %%
sc=StandardScaler()
temp = sc.fit(X_train[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]])
X_train[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]] = temp.transform(X_train[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]])
X_test[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]] = temp.transform(X_test[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]])
X_val[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]] = temp.transform(X_val[["CreditScore","Age","Tenure","Balance","EstimatedSalary"]])

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model Evaluation Criterion

# %% [markdown]
# In this circumstance, we want to predict that the customer is not exiting but they are actually exiting. This is more important because it may cause loss to the banks due to the lack of care for those customers on the fence about exiting.

# %% [markdown]
# Thus, we are aiming to maximize Recall in hopes of minimizing false negatives.

# %%
def make_confusion_matrix(cf,
                          group_names=None,
                          categories='auto',
                          count=True,
                          percent=True,
                          cbar=True,
                          xyticks=True,
                          xyplotlabels=True,
                          sum_stats=True,
                          figsize=None,
                          cmap='Blues',
                          title=None):
    '''
    This function will make a pretty plot of an sklearn Confusion Matrix cm using a Seaborn heatmap visualization.
    Arguments
    '''


    # CODE TO GENERATE TEXT INSIDE EACH SQUARE
    blanks = ['' for i in range(cf.size)]

    if group_names and len(group_names)==cf.size:
        group_labels = ["{}\n".format(value) for value in group_names]
    else:
        group_labels = blanks

    if count:
        group_counts = ["{0:0.0f}\n".format(value) for value in cf.flatten()]
    else:
        group_counts = blanks

    if percent:
        group_percentages = ["{0:.2%}".format(value) for value in cf.flatten()/np.sum(cf)]
    else:
        group_percentages = blanks

    box_labels = [f"{v1}{v2}{v3}".strip() for v1, v2, v3 in zip(group_labels,group_counts,group_percentages)]
    box_labels = np.asarray(box_labels).reshape(cf.shape[0],cf.shape[1])


    # CODE TO GENERATE SUMMARY STATISTICS & TEXT FOR SUMMARY STATS
    if sum_stats:
        #Accuracy is sum of diagonal divided by total observations
        accuracy  = np.trace(cf) / float(np.sum(cf))

        #if it is a binary confusion matrix, show some more stats
        if len(cf)==2:
            #Metrics for Binary Confusion Matrices
            precision = cf[1,1] / sum(cf[:,1])
            recall    = cf[1,1] / sum(cf[1,:])
            f1_score  = 2*precision*recall / (precision + recall)
            stats_text = "\n\nAccuracy={:0.3f}\nPrecision={:0.3f}\nRecall={:0.3f}\nF1 Score={:0.3f}".format(
                accuracy,precision,recall,f1_score)
        else:
            stats_text = "\n\nAccuracy={:0.3f}".format(accuracy)
    else:
        stats_text = ""


    # SET FIGURE PARAMETERS ACCORDING TO OTHER ARGUMENTS
    if figsize==None:
        #Get default figure size if not set
        figsize = plt.rcParams.get('figure.figsize')

    if xyticks==False:
        #Do not show categories if xyticks is False
        categories=False


    # MAKE THE HEATMAP VISUALIZATION
    plt.figure(figsize=figsize)
    sns.heatmap(cf,annot=box_labels,fmt="",cmap=cmap,cbar=cbar,xticklabels=categories,yticklabels=categories)

    if xyplotlabels:
        plt.ylabel('True label')
        plt.xlabel('Predicted label' + stats_text)
    else:
        plt.xlabel(stats_text)

    if title:
        plt.title(title)

# %% [markdown]
# ### Model Building: Neural Network

# %%
backend.clear_session()
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
# Initializing the ANN
classifier = Sequential()
classifier.add(Dense(activation = 'relu', input_dim = 11, units=64))

classifier.add(Dense(32, activation='relu'))

classifier.add(Dense(1, activation = 'sigmoid'))

# %%
classifier.compile(optimizer='SGD', loss='binary_crossentropy', metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=classifier.fit(X_train, y_train,
          validation_data=(X_val,y_val),
          epochs=100,
          batch_size=32)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.5052 - accuracy: 0.7894 - val_loss: 0.4681 - val_accuracy: 0.7962
# Epoch 2/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4607 - accuracy: 0.7970 - val_loss: 0.4533 - val_accuracy: 0.7962
# Epoch 3/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4471 - accuracy: 0.7998 - val_loss: 0.4450 - val_accuracy: 0.7956
# Epoch 4/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4383 - accuracy: 0.8042 - val_loss: 0.4397 - val_accuracy: 0.8081
# Epoch 5/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4324 - accuracy: 0.8091 - val_loss: 0.4355 - val_accuracy: 0.8087
# Epoch 6/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4280 - accuracy: 0.8133 - val_loss: 0.4325 - val_accuracy: 0.8138
# Epoch 7/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4247 - accuracy: 0.8167 - val_loss: 0.4302 - val_accuracy: 0.8163
# Epoch 8/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4211 - accuracy: 0.8192 - val_loss: 0.4304 - val_accuracy: 0.8131
# Epoch 9/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4196 - accuracy: 0.8189 - val_loss: 0.4268 - val_accuracy: 0.8181
# Epoch 10/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4175 - accuracy: 0.8206 - val_loss: 0.4256 - val_accuracy: 0.8213
# Epoch 11/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4158 - accuracy: 0.8208 - val_loss: 0.4248 - val_accuracy: 0.8200
# Epoch 12/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4142 - accuracy: 0.8209 - val_loss: 0.4232 - val_accuracy: 0.8238
# Epoch 13/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8239 - val_loss: 0.4223 - val_accuracy: 0.8250
# Epoch 14/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.8239 - val_loss: 0.4218 - val_accuracy: 0.8256
# Epoch 15/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8242 - val_loss: 0.4209 - val_accuracy: 0.8269
# Epoch 16/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4088 - accuracy: 0.8252 - val_loss: 0.4201 - val_accuracy: 0.8269
# Epoch 17/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.8272 - val_loss: 0.4187 - val_accuracy: 0.8263
# Epoch 18/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8267 - val_loss: 0.4182 - val_accuracy: 0.8281
# Epoch 19/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8272 - val_loss: 0.4178 - val_accuracy: 0.8275
# Epoch 20/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4046 - accuracy: 0.8277 - val_loss: 0.4168 - val_accuracy: 0.8319
# Epoch 21/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4035 - accuracy: 0.8286 - val_loss: 0.4160 - val_accuracy: 0.8300
# Epoch 22/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8288 - val_loss: 0.4158 - val_accuracy: 0.8300
# Epoch 23/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8300 - val_loss: 0.4147 - val_accuracy: 0.8300
# Epoch 24/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8313 - val_loss: 0.4131 - val_accuracy: 0.8300
# Epoch 25/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3993 - accuracy: 0.8311 - val_loss: 0.4123 - val_accuracy: 0.8325
# Epoch 26/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3981 - accuracy: 0.8334 - val_loss: 0.4120 - val_accuracy: 0.8338
# Epoch 27/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3970 - accuracy: 0.8327 - val_loss: 0.4123 - val_accuracy: 0.8306
# Epoch 28/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8344 - val_loss: 0.4111 - val_accuracy: 0.8331
# Epoch 29/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8345 - val_loss: 0.4106 - val_accuracy: 0.8338
# Epoch 30/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3944 - accuracy: 0.8356 - val_loss: 0.4093 - val_accuracy: 0.8363
# Epoch 31/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3935 - accuracy: 0.8342 - val_loss: 0.4084 - val_accuracy: 0.8369
# Epoch 32/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8363 - val_loss: 0.4080 - val_accuracy: 0.8350
# Epoch 33/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3915 - accuracy: 0.8372 - val_loss: 0.4069 - val_accuracy: 0.8363
# Epoch 34/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3906 - accuracy: 0.8372 - val_loss: 0.4063 - val_accuracy: 0.8381
# Epoch 35/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3895 - accuracy: 0.8366 - val_loss: 0.4056 - val_accuracy: 0.8369
# Epoch 36/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3884 - accuracy: 0.8373 - val_loss: 0.4048 - val_accuracy: 0.8356
# Epoch 37/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8381 - val_loss: 0.4044 - val_accuracy: 0.8375
# Epoch 38/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3866 - accuracy: 0.8395 - val_loss: 0.4038 - val_accuracy: 0.8344
# Epoch 39/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8398 - val_loss: 0.4021 - val_accuracy: 0.8381
# Epoch 40/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.8392 - val_loss: 0.4016 - val_accuracy: 0.8375
# Epoch 41/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3834 - accuracy: 0.8425 - val_loss: 0.4009 - val_accuracy: 0.8394
# Epoch 42/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.8417 - val_loss: 0.4004 - val_accuracy: 0.8413
# Epoch 43/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3817 - accuracy: 0.8406 - val_loss: 0.3990 - val_accuracy: 0.8381
# Epoch 44/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8420 - val_loss: 0.3985 - val_accuracy: 0.8413
# Epoch 45/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3793 - accuracy: 0.8408 - val_loss: 0.3976 - val_accuracy: 0.8425
# Epoch 46/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3783 - accuracy: 0.8431 - val_loss: 0.3959 - val_accuracy: 0.8450
# Epoch 47/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3771 - accuracy: 0.8447 - val_loss: 0.3947 - val_accuracy: 0.8419
# Epoch 48/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3761 - accuracy: 0.8447 - val_loss: 0.3943 - val_accuracy: 0.8438
# Epoch 49/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3752 - accuracy: 0.8452 - val_loss: 0.3927 - val_accuracy: 0.8494
# Epoch 50/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3735 - accuracy: 0.8450 - val_loss: 0.3958 - val_accuracy: 0.8375
# Epoch 51/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8450 - val_loss: 0.3907 - val_accuracy: 0.8481
# Epoch 52/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3715 - accuracy: 0.8462 - val_loss: 0.3897 - val_accuracy: 0.8462
# Epoch 53/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3706 - accuracy: 0.8481 - val_loss: 0.3908 - val_accuracy: 0.8456
# Epoch 54/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3694 - accuracy: 0.8478 - val_loss: 0.3881 - val_accuracy: 0.8462
# Epoch 55/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8481 - val_loss: 0.3868 - val_accuracy: 0.8469
# Epoch 56/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3671 - accuracy: 0.8487 - val_loss: 0.3851 - val_accuracy: 0.8487
# Epoch 57/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3661 - accuracy: 0.8491 - val_loss: 0.3843 - val_accuracy: 0.8487
# Epoch 58/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3648 - accuracy: 0.8500 - val_loss: 0.3831 - val_accuracy: 0.8494
# Epoch 59/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3634 - accuracy: 0.8498 - val_loss: 0.3830 - val_accuracy: 0.8456
# Epoch 60/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3627 - accuracy: 0.8495 - val_loss: 0.3813 - val_accuracy: 0.8506
# Epoch 61/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.8519 - val_loss: 0.3798 - val_accuracy: 0.8512
# Epoch 62/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3603 - accuracy: 0.8517 - val_loss: 0.3785 - val_accuracy: 0.8487
# Epoch 63/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3595 - accuracy: 0.8523 - val_loss: 0.3784 - val_accuracy: 0.8500
# Epoch 64/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3585 - accuracy: 0.8527 - val_loss: 0.3775 - val_accuracy: 0.8519
# Epoch 65/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3572 - accuracy: 0.8520 - val_loss: 0.3778 - val_accuracy: 0.8475
# Epoch 66/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3560 - accuracy: 0.8534 - val_loss: 0.3755 - val_accuracy: 0.8494
# Epoch 67/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8550 - val_loss: 0.3733 - val_accuracy: 0.8481
# Epoch 68/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3541 - accuracy: 0.8539 - val_loss: 0.3735 - val_accuracy: 0.8512
# Epoch 69/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3529 - accuracy: 0.8539 - val_loss: 0.3736 - val_accuracy: 0.8494
# Epoch 70/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3520 - accuracy: 0.8539 - val_loss: 0.3727 - val_accuracy: 0.8512
# Epoch 71/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3514 - accuracy: 0.8547 - val_loss: 0.3695 - val_accuracy: 0.8494
# Epoch 72/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3501 - accuracy: 0.8547 - val_loss: 0.3687 - val_accuracy: 0.8512
# Epoch 73/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3492 - accuracy: 0.8553 - val_loss: 0.3691 - val_accuracy: 0.8544
# Epoch 74/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3480 - accuracy: 0.8577 - val_loss: 0.3695 - val_accuracy: 0.8519
# Epoch 75/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.8559 - val_loss: 0.3661 - val_accuracy: 0.8525
# Epoch 76/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3461 - accuracy: 0.8555 - val_loss: 0.3645 - val_accuracy: 0.8531
# Epoch 77/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3443 - accuracy: 0.8548 - val_loss: 0.3661 - val_accuracy: 0.8456
# Epoch 78/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3446 - accuracy: 0.8583 - val_loss: 0.3635 - val_accuracy: 0.8506
# Epoch 79/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3433 - accuracy: 0.8603 - val_loss: 0.3631 - val_accuracy: 0.8487
# Epoch 80/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8581 - val_loss: 0.3638 - val_accuracy: 0.8487
# Epoch 81/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3410 - accuracy: 0.8602 - val_loss: 0.3642 - val_accuracy: 0.8537
# Epoch 82/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3406 - accuracy: 0.8597 - val_loss: 0.3617 - val_accuracy: 0.8519
# Epoch 83/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3398 - accuracy: 0.8609 - val_loss: 0.3643 - val_accuracy: 0.8525
# Epoch 84/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8587 - val_loss: 0.3625 - val_accuracy: 0.8494
# Epoch 85/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8614 - val_loss: 0.3619 - val_accuracy: 0.8537
# Epoch 86/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3378 - accuracy: 0.8608 - val_loss: 0.3602 - val_accuracy: 0.8525
# Epoch 87/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3369 - accuracy: 0.8611 - val_loss: 0.3583 - val_accuracy: 0.8525
# Epoch 88/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3363 - accuracy: 0.8622 - val_loss: 0.3598 - val_accuracy: 0.8537
# Epoch 89/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3356 - accuracy: 0.8642 - val_loss: 0.3579 - val_accuracy: 0.8531
# Epoch 90/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3346 - accuracy: 0.8617 - val_loss: 0.3609 - val_accuracy: 0.8512
# Epoch 91/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3337 - accuracy: 0.8653 - val_loss: 0.3589 - val_accuracy: 0.8544
# Epoch 92/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3330 - accuracy: 0.8623 - val_loss: 0.3597 - val_accuracy: 0.8537
# Epoch 93/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3326 - accuracy: 0.8609 - val_loss: 0.3575 - val_accuracy: 0.8550
# Epoch 94/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3320 - accuracy: 0.8642 - val_loss: 0.3562 - val_accuracy: 0.8537
# Epoch 95/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3311 - accuracy: 0.8653 - val_loss: 0.3587 - val_accuracy: 0.8481
# Epoch 96/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3301 - accuracy: 0.8634 - val_loss: 0.3558 - val_accuracy: 0.8544
# Epoch 97/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3297 - accuracy: 0.8655 - val_loss: 0.3561 - val_accuracy: 0.8562
# Epoch 98/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3289 - accuracy: 0.8639 - val_loss: 0.3617 - val_accuracy: 0.8519
# Epoch 99/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8652 - val_loss: 0.3548 - val_accuracy: 0.8550
# Epoch 100/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.8666 - val_loss: 0.3555 - val_accuracy: 0.8531

# %% [markdown]
# **Loss function**

# %%
# Capturing learning history per epoch
hist  = pd.DataFrame(history.history)
hist['epoch'] = history.epoch

# Plotting accuracy at different epochs
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train" , "valid") , loc =0)


results = classifier.evaluate(X_test, y_test)
# Out:
# 63/63 [==============================] - 0s 806us/step - loss: 0.3461 - accuracy: 0.8575

# %% [markdown]
# **Confusion matrix**

# %%
y_pred1=classifier.predict(X_val)

#Let's predict using default threshold
y_pred1 = (y_pred1 > 0.5)
cm2=confusion_matrix(y_val, y_pred1)
labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm2,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')
# Out:
# 50/50 [==============================] - 0s 734us/step

# %% [markdown]
# ### Model Building: Neural Network model with Adam Optimizer

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
def create_model():
      ## Initializing the neural network
      model = Sequential()


      model.add(Dense(64,activation='relu',input_dim = X_train.shape[1]))


      model.add(Dense(32,activation='relu'))


      model.add(Dense(1, activation = 'sigmoid'))


      optimizer = tf.keras.optimizers.Adam(0.001)


      model.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])
      return model

# %%
model=create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train,y_train,batch_size=32,validation_data=(X_val,y_val),epochs=100,verbose=1)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4546 - accuracy: 0.8052 - val_loss: 0.4346 - val_accuracy: 0.8094
# Epoch 2/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4163 - accuracy: 0.8238 - val_loss: 0.4208 - val_accuracy: 0.8169
# Epoch 3/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4046 - accuracy: 0.8286 - val_loss: 0.4144 - val_accuracy: 0.8275
# Epoch 4/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3953 - accuracy: 0.8323 - val_loss: 0.4151 - val_accuracy: 0.8181
# Epoch 5/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3852 - accuracy: 0.8370 - val_loss: 0.4026 - val_accuracy: 0.8331
# Epoch 6/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3772 - accuracy: 0.8431 - val_loss: 0.3932 - val_accuracy: 0.8388
# Epoch 7/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3703 - accuracy: 0.8445 - val_loss: 0.3815 - val_accuracy: 0.8431
# Epoch 8/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3622 - accuracy: 0.8445 - val_loss: 0.3772 - val_accuracy: 0.8475
# Epoch 9/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3554 - accuracy: 0.8520 - val_loss: 0.3741 - val_accuracy: 0.8438
# Epoch 10/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3490 - accuracy: 0.8562 - val_loss: 0.3623 - val_accuracy: 0.8531
# Epoch 11/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8536 - val_loss: 0.3814 - val_accuracy: 0.8456
# Epoch 12/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8603 - val_loss: 0.3642 - val_accuracy: 0.8550
# Epoch 13/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3350 - accuracy: 0.8617 - val_loss: 0.3582 - val_accuracy: 0.8487
# Epoch 14/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3305 - accuracy: 0.8625 - val_loss: 0.3639 - val_accuracy: 0.8475
# Epoch 15/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3283 - accuracy: 0.8636 - val_loss: 0.3644 - val_accuracy: 0.8500
# Epoch 16/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3262 - accuracy: 0.8636 - val_loss: 0.3559 - val_accuracy: 0.8525
# Epoch 17/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3219 - accuracy: 0.8666 - val_loss: 0.3549 - val_accuracy: 0.8569
# Epoch 18/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3188 - accuracy: 0.8673 - val_loss: 0.3578 - val_accuracy: 0.8519
# Epoch 19/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3179 - accuracy: 0.8686 - val_loss: 0.3649 - val_accuracy: 0.8544
# Epoch 20/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3160 - accuracy: 0.8681 - val_loss: 0.3521 - val_accuracy: 0.8550
# Epoch 21/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.8669 - val_loss: 0.3551 - val_accuracy: 0.8544
# Epoch 22/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3142 - accuracy: 0.8678 - val_loss: 0.3518 - val_accuracy: 0.8550
# Epoch 23/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3122 - accuracy: 0.8716 - val_loss: 0.3538 - val_accuracy: 0.8569
# Epoch 24/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3101 - accuracy: 0.8727 - val_loss: 0.3531 - val_accuracy: 0.8544
# Epoch 25/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3086 - accuracy: 0.8725 - val_loss: 0.3565 - val_accuracy: 0.8550
# Epoch 26/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.8733 - val_loss: 0.3551 - val_accuracy: 0.8519
# Epoch 27/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3076 - accuracy: 0.8727 - val_loss: 0.3631 - val_accuracy: 0.8537
# Epoch 28/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3071 - accuracy: 0.8736 - val_loss: 0.3578 - val_accuracy: 0.8556
# Epoch 29/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3068 - accuracy: 0.8720 - val_loss: 0.3569 - val_accuracy: 0.8519
# Epoch 30/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3029 - accuracy: 0.8744 - val_loss: 0.3573 - val_accuracy: 0.8475
# Epoch 31/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3032 - accuracy: 0.8733 - val_loss: 0.3638 - val_accuracy: 0.8506
# Epoch 32/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3027 - accuracy: 0.8722 - val_loss: 0.3568 - val_accuracy: 0.8531
# Epoch 33/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3013 - accuracy: 0.8717 - val_loss: 0.3593 - val_accuracy: 0.8519
# Epoch 34/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3021 - accuracy: 0.8731 - val_loss: 0.3578 - val_accuracy: 0.8481
# Epoch 35/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8745 - val_loss: 0.3567 - val_accuracy: 0.8550
# Epoch 36/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8717 - val_loss: 0.3573 - val_accuracy: 0.8506
# Epoch 37/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8777 - val_loss: 0.3560 - val_accuracy: 0.8544
# Epoch 38/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2960 - accuracy: 0.8753 - val_loss: 0.3615 - val_accuracy: 0.8494
# Epoch 39/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2966 - accuracy: 0.8745 - val_loss: 0.3659 - val_accuracy: 0.8475
# Epoch 40/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2953 - accuracy: 0.8784 - val_loss: 0.3736 - val_accuracy: 0.8462
# Epoch 41/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2958 - accuracy: 0.8755 - val_loss: 0.3698 - val_accuracy: 0.8494
# Epoch 42/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2939 - accuracy: 0.8775 - val_loss: 0.3633 - val_accuracy: 0.8494
# Epoch 43/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2931 - accuracy: 0.8764 - val_loss: 0.3689 - val_accuracy: 0.8481
# Epoch 44/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2925 - accuracy: 0.8767 - val_loss: 0.3669 - val_accuracy: 0.8444
# Epoch 45/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2920 - accuracy: 0.8778 - val_loss: 0.3625 - val_accuracy: 0.8512
# Epoch 46/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2907 - accuracy: 0.8786 - val_loss: 0.3682 - val_accuracy: 0.8475
# Epoch 47/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2892 - accuracy: 0.8798 - val_loss: 0.3755 - val_accuracy: 0.8500
# Epoch 48/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2906 - accuracy: 0.8789 - val_loss: 0.3645 - val_accuracy: 0.8475
# Epoch 49/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2871 - accuracy: 0.8803 - val_loss: 0.3746 - val_accuracy: 0.8462
# Epoch 50/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2883 - accuracy: 0.8794 - val_loss: 0.3662 - val_accuracy: 0.8469
# Epoch 51/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2863 - accuracy: 0.8798 - val_loss: 0.3683 - val_accuracy: 0.8525
# Epoch 52/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2839 - accuracy: 0.8813 - val_loss: 0.3708 - val_accuracy: 0.8512
# Epoch 53/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2832 - accuracy: 0.8803 - val_loss: 0.3676 - val_accuracy: 0.8587
# Epoch 54/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2824 - accuracy: 0.8800 - val_loss: 0.3803 - val_accuracy: 0.8494
# Epoch 55/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2830 - accuracy: 0.8830 - val_loss: 0.3746 - val_accuracy: 0.8438
# Epoch 56/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2823 - accuracy: 0.8830 - val_loss: 0.3703 - val_accuracy: 0.8494
# Epoch 57/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2821 - accuracy: 0.8836 - val_loss: 0.3742 - val_accuracy: 0.8419
# Epoch 58/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2803 - accuracy: 0.8845 - val_loss: 0.3737 - val_accuracy: 0.8500
# Epoch 59/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2785 - accuracy: 0.8839 - val_loss: 0.3741 - val_accuracy: 0.8469
# Epoch 60/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2781 - accuracy: 0.8833 - val_loss: 0.3908 - val_accuracy: 0.8469
# Epoch 61/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2784 - accuracy: 0.8848 - val_loss: 0.3727 - val_accuracy: 0.8506
# Epoch 62/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2774 - accuracy: 0.8841 - val_loss: 0.3731 - val_accuracy: 0.8494
# Epoch 63/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8845 - val_loss: 0.3790 - val_accuracy: 0.8450
# Epoch 64/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 0.8863 - val_loss: 0.3818 - val_accuracy: 0.8444
# Epoch 65/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2745 - accuracy: 0.8861 - val_loss: 0.3854 - val_accuracy: 0.8462
# Epoch 66/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2747 - accuracy: 0.8858 - val_loss: 0.3790 - val_accuracy: 0.8431
# Epoch 67/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2726 - accuracy: 0.8864 - val_loss: 0.3854 - val_accuracy: 0.8500
# Epoch 68/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2721 - accuracy: 0.8867 - val_loss: 0.3787 - val_accuracy: 0.8462
# Epoch 69/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8852 - val_loss: 0.3764 - val_accuracy: 0.8512
# Epoch 70/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.8880 - val_loss: 0.3898 - val_accuracy: 0.8481
# Epoch 71/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2716 - accuracy: 0.8888 - val_loss: 0.3799 - val_accuracy: 0.8469
# Epoch 72/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.8855 - val_loss: 0.3774 - val_accuracy: 0.8438
# Epoch 73/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2671 - accuracy: 0.8872 - val_loss: 0.3872 - val_accuracy: 0.8350
# Epoch 74/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2680 - accuracy: 0.8900 - val_loss: 0.3815 - val_accuracy: 0.8469
# Epoch 75/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2671 - accuracy: 0.8906 - val_loss: 0.3893 - val_accuracy: 0.8381
# Epoch 76/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2683 - accuracy: 0.8888 - val_loss: 0.3903 - val_accuracy: 0.8462
# Epoch 77/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2670 - accuracy: 0.8888 - val_loss: 0.3832 - val_accuracy: 0.8425
# Epoch 78/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2669 - accuracy: 0.8878 - val_loss: 0.3851 - val_accuracy: 0.8431
# Epoch 79/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2659 - accuracy: 0.8894 - val_loss: 0.3868 - val_accuracy: 0.8388
# Epoch 80/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2663 - accuracy: 0.8909 - val_loss: 0.3812 - val_accuracy: 0.8450
# Epoch 81/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.8906 - val_loss: 0.3937 - val_accuracy: 0.8438
# Epoch 82/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2626 - accuracy: 0.8906 - val_loss: 0.3811 - val_accuracy: 0.8500
# Epoch 83/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2599 - accuracy: 0.8925 - val_loss: 0.3845 - val_accuracy: 0.8419
# Epoch 84/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2611 - accuracy: 0.8930 - val_loss: 0.3906 - val_accuracy: 0.8344
# Epoch 85/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2605 - accuracy: 0.8911 - val_loss: 0.3865 - val_accuracy: 0.8481
# Epoch 86/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.8941 - val_loss: 0.3869 - val_accuracy: 0.8419
# Epoch 87/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2596 - accuracy: 0.8941 - val_loss: 0.3902 - val_accuracy: 0.8456
# Epoch 88/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.8948 - val_loss: 0.3861 - val_accuracy: 0.8444
# Epoch 89/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2568 - accuracy: 0.8939 - val_loss: 0.3954 - val_accuracy: 0.8406
# Epoch 90/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2572 - accuracy: 0.8916 - val_loss: 0.3924 - val_accuracy: 0.8375
# Epoch 91/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2573 - accuracy: 0.8955 - val_loss: 0.4138 - val_accuracy: 0.8450
# Epoch 92/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2557 - accuracy: 0.8970 - val_loss: 0.3908 - val_accuracy: 0.8394
# Epoch 93/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2565 - accuracy: 0.8958 - val_loss: 0.4010 - val_accuracy: 0.8413
# Epoch 94/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2563 - accuracy: 0.8967 - val_loss: 0.3930 - val_accuracy: 0.8313
# Epoch 95/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2542 - accuracy: 0.8933 - val_loss: 0.3954 - val_accuracy: 0.8388
# Epoch 96/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2545 - accuracy: 0.8961 - val_loss: 0.4042 - val_accuracy: 0.8444
# Epoch 97/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.2548 - accuracy: 0.8938 - val_loss: 0.3860 - val_accuracy: 0.8406
# Epoch 98/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.2520 - accuracy: 0.8963 - val_loss: 0.3952 - val_accuracy: 0.8413
# Epoch 99/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2537 - accuracy: 0.8969 - val_loss: 0.3934 - val_accuracy: 0.8388
# Epoch 100/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.2495 - accuracy: 0.8995 - val_loss: 0.3968 - val_accuracy: 0.8438

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Best possible solution: Early stopping

# %%
#Importing classback API
# Defining Early stopping
es_cb = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5)

model_e=create_model()


history_e = model_e.fit(X_train,y_train,batch_size=32,epochs=100,verbose=1,validation_data=(X_val,y_val),callbacks=[es_cb])
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4547 - accuracy: 0.7966 - val_loss: 0.4311 - val_accuracy: 0.8112
# Epoch 2/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8214 - val_loss: 0.4218 - val_accuracy: 0.8200
# Epoch 3/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4030 - accuracy: 0.8291 - val_loss: 0.4126 - val_accuracy: 0.8319
# Epoch 4/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3926 - accuracy: 0.8367 - val_loss: 0.4118 - val_accuracy: 0.8269
# Epoch 5/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3814 - accuracy: 0.8369 - val_loss: 0.3976 - val_accuracy: 0.8338
# Epoch 6/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3715 - accuracy: 0.8427 - val_loss: 0.3863 - val_accuracy: 0.8469
# Epoch 7/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3636 - accuracy: 0.8484 - val_loss: 0.3806 - val_accuracy: 0.8462
# Epoch 8/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8472 - val_loss: 0.3704 - val_accuracy: 0.8494
# Epoch 9/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8556 - val_loss: 0.3698 - val_accuracy: 0.8450
# Epoch 10/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3433 - accuracy: 0.8564 - val_loss: 0.3566 - val_accuracy: 0.8500
# Epoch 11/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8592 - val_loss: 0.3652 - val_accuracy: 0.8519
# Epoch 12/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8620 - val_loss: 0.3575 - val_accuracy: 0.8587
# Epoch 13/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8647 - val_loss: 0.3515 - val_accuracy: 0.8581
# Epoch 14/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3262 - accuracy: 0.8633 - val_loss: 0.3538 - val_accuracy: 0.8556
# Epoch 15/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3242 - accuracy: 0.8659 - val_loss: 0.3557 - val_accuracy: 0.8550
# Epoch 16/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3216 - accuracy: 0.8653 - val_loss: 0.3521 - val_accuracy: 0.8544
# Epoch 17/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3185 - accuracy: 0.8684 - val_loss: 0.3487 - val_accuracy: 0.8587
# Epoch 18/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3151 - accuracy: 0.8684 - val_loss: 0.3516 - val_accuracy: 0.8569
# Epoch 19/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3142 - accuracy: 0.8720 - val_loss: 0.3641 - val_accuracy: 0.8544
# Epoch 20/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3124 - accuracy: 0.8700 - val_loss: 0.3461 - val_accuracy: 0.8612
# Epoch 21/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3120 - accuracy: 0.8681 - val_loss: 0.3486 - val_accuracy: 0.8569
# Epoch 22/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3106 - accuracy: 0.8708 - val_loss: 0.3487 - val_accuracy: 0.8606
# Epoch 23/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3090 - accuracy: 0.8698 - val_loss: 0.3484 - val_accuracy: 0.8606
# Epoch 24/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3062 - accuracy: 0.8720 - val_loss: 0.3498 - val_accuracy: 0.8600
# Epoch 25/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3053 - accuracy: 0.8728 - val_loss: 0.3554 - val_accuracy: 0.8562

# %%
# Plotting Train Loss vs Validation Loss
plt.plot(history_e.history['loss'])
plt.plot(history_e.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# predict probabilities
yhat = model_e.predict(X_train)
# keep probabilities for the positive outcome only
yhat = yhat[:, 0]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_train, yhat)
# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 200/200 [==============================] - 0s 658us/step
# Best Threshold=0.163233, G-Mean=0.815

# %%
#Predicting the results using best as a threshold
y_pred_e=model_e.predict(X_val)
y_pred_e = (y_pred_e > thresholds[ix])
y_pred_e
# Out:
# 50/50 [==============================] - 0s 725us/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
cr=metrics.classification_report(y_val,y_pred_e)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.80      0.86      1274
#            1       0.50      0.76      0.60       326
#
#     accuracy                           0.79      1600
#    macro avg       0.71      0.78      0.73      1600
# weighted avg       0.84      0.79      0.81      1600

# %% [markdown]
# **Confusion matrix**

# %%
cm1=confusion_matrix(y_val, y_pred_e)
labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm1,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %% [markdown]
# ### Model Improvement: Neural Network model with Dropout

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_3 = Sequential()

#Adding the input layer with 32 neurons and relu as activation function
model_3.add(Dense(32,activation='relu',input_dim = X_train.shape[1]))


model_3.add(Dropout(0.2))

# Adding the first hidden layer with 16 neurons with relu as activation functions
model_3.add(Dense(16,activation='relu'))


model_3.add(Dropout(0.1))
# Adding the second hidden layer with 8 neurons with relu as activation functions
model_3.add(Dense(8,activation='relu'))

# Adding the output layer
model_3.add(Dense(1, activation = 'sigmoid'))

# %%
model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,057
# Trainable params: 1,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Initialize the ANN with Adam optimizer
optimizer = tf.keras.optimizers.Adam(0.001)


model_3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
#Fitting the ANN with batch_size = 32 and 100 epochs
history_3 = model_3.fit(X_train,y_train,batch_size=32,epochs=100,verbose=1,validation_data=(X_val,y_val),callbacks=[es_cb])
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 2ms/step - loss: 0.4900 - accuracy: 0.7983 - val_loss: 0.4415 - val_accuracy: 0.8012
# Epoch 2/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.8045 - val_loss: 0.4283 - val_accuracy: 0.8069
# Epoch 3/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.8127 - val_loss: 0.4229 - val_accuracy: 0.8188
# Epoch 4/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4241 - accuracy: 0.8127 - val_loss: 0.4201 - val_accuracy: 0.8250
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4202 - accuracy: 0.8216 - val_loss: 0.4146 - val_accuracy: 0.8213
# Epoch 6/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8183 - val_loss: 0.4112 - val_accuracy: 0.8250
# Epoch 7/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4137 - accuracy: 0.8220 - val_loss: 0.4079 - val_accuracy: 0.8300
# Epoch 8/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4095 - accuracy: 0.8273 - val_loss: 0.4063 - val_accuracy: 0.8288
# Epoch 9/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8314 - val_loss: 0.4028 - val_accuracy: 0.8325
# Epoch 10/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.4008 - accuracy: 0.8322 - val_loss: 0.3993 - val_accuracy: 0.8338
# Epoch 11/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8323 - val_loss: 0.3974 - val_accuracy: 0.8331
# Epoch 12/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8358 - val_loss: 0.3957 - val_accuracy: 0.8344
# Epoch 13/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3932 - accuracy: 0.8353 - val_loss: 0.3919 - val_accuracy: 0.8356
# Epoch 14/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8377 - val_loss: 0.3942 - val_accuracy: 0.8363
# Epoch 15/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3874 - accuracy: 0.8395 - val_loss: 0.3859 - val_accuracy: 0.8419
# Epoch 16/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3910 - accuracy: 0.8341 - val_loss: 0.3860 - val_accuracy: 0.8400
# Epoch 17/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3856 - accuracy: 0.8388 - val_loss: 0.3837 - val_accuracy: 0.8419
# Epoch 18/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8420 - val_loss: 0.3808 - val_accuracy: 0.8425
# Epoch 19/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3849 - accuracy: 0.8397 - val_loss: 0.3863 - val_accuracy: 0.8431
# Epoch 20/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3802 - accuracy: 0.8419 - val_loss: 0.3782 - val_accuracy: 0.8444
# Epoch 21/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3740 - accuracy: 0.8447 - val_loss: 0.3763 - val_accuracy: 0.8475
# Epoch 22/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8455 - val_loss: 0.3709 - val_accuracy: 0.8462
# Epoch 23/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3702 - accuracy: 0.8487 - val_loss: 0.3685 - val_accuracy: 0.8450
# Epoch 24/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3691 - accuracy: 0.8469 - val_loss: 0.3653 - val_accuracy: 0.8506
# Epoch 25/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3659 - accuracy: 0.8530 - val_loss: 0.3651 - val_accuracy: 0.8500
# Epoch 26/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3639 - accuracy: 0.8519 - val_loss: 0.3635 - val_accuracy: 0.8469
# Epoch 27/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3619 - accuracy: 0.8552 - val_loss: 0.3654 - val_accuracy: 0.8456
# Epoch 28/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3596 - accuracy: 0.8523 - val_loss: 0.3593 - val_accuracy: 0.8481
# Epoch 29/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3601 - accuracy: 0.8523 - val_loss: 0.3550 - val_accuracy: 0.8500
# Epoch 30/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3563 - accuracy: 0.8562 - val_loss: 0.3530 - val_accuracy: 0.8494
# Epoch 31/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3484 - accuracy: 0.8620 - val_loss: 0.3523 - val_accuracy: 0.8550
# Epoch 32/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8569 - val_loss: 0.3500 - val_accuracy: 0.8525
# Epoch 33/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3496 - accuracy: 0.8562 - val_loss: 0.3455 - val_accuracy: 0.8562
# Epoch 34/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3494 - accuracy: 0.8558 - val_loss: 0.3483 - val_accuracy: 0.8575
# Epoch 35/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3453 - accuracy: 0.8623 - val_loss: 0.3477 - val_accuracy: 0.8606
# Epoch 36/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8572 - val_loss: 0.3475 - val_accuracy: 0.8600
# Epoch 37/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3432 - accuracy: 0.8602 - val_loss: 0.3481 - val_accuracy: 0.8612
# Epoch 38/100
# 200/200 [==============================] - 0s 1ms/step - loss: 0.3414 - accuracy: 0.8622 - val_loss: 0.3461 - val_accuracy: 0.8606

# %% [markdown]
# **Loss function**

# %%
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
# predict probabilities
yhat = model_3.predict(X_train)
# keep probabilities for the positive outcome only
yhat = yhat[:, 0]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_train, yhat)
# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 200/200 [==============================] - 0s 718us/step
# Best Threshold=0.197977, G-Mean=0.794

# %% [markdown]
# **Prediction**

# %%
#Predicting the results using best as a threshold
y_pred_e=model_3.predict(X_val)
y_pred_3 = (y_pred_e > thresholds[ix])
y_pred_3
# Out:
# 50/50 [==============================] - 0s 771us/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
from sklearn import metrics
cr=metrics.classification_report(y_val,y_pred_3)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1274
#            1       0.51      0.74      0.60       326
#
#     accuracy                           0.80      1600
#    macro avg       0.71      0.78      0.73      1600
# weighted avg       0.84      0.80      0.81      1600

# %%
cm1=confusion_matrix(y_val, y_pred_3)
labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm1,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %% [markdown]
# ### Model Improvement: Neural Network model with Hyperparameter tuning

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
def create_model_v2(dropout_rate=0.1,lr=0.001,layer_1=64,layer_2=32):
    np.random.seed(1337)

    #Initializing the neural network
    model = Sequential()

    # This adds the input layer (by specifying input dimension)
    model.add(Dense(layer_1,activation='relu',input_dim = X_train.shape[1]))


    model.add(Dropout(0.5))

    # # Adding the hidden layer
    # Notice that we do not need to specify input dim.
    model.add(Dense(layer_2,activation='relu'))

    # # Adding the output layer
    # Notice that we do not need to specify input dim.
    # we have an output of 1 node, which is the the desired dimensions of our output (stay with the bank or not)
    # We use the sigmoid because we want probability outcomes
    model.add(Dense(1, activation='sigmoid'))

    # Adding Adam initializer
    optimizer = tf.keras.optimizers.Adam(learning_rate=lr)

    model.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
keras_estimator = KerasClassifier(build_fn=create_model_v2, verbose=1)

# %%
# define the grid search parameters
param_grid = {
    'batch_size':[40, 64, 128],
    "lr":[0.01,0.001,0.1]}


kfold_splits = 3
grid = GridSearchCV(estimator=keras_estimator,
                    verbose=1,
                    cv=kfold_splits,
                    param_grid=param_grid,n_jobs=-1)

# %%
grid_result = grid.fit(X_train, y_train,validation_data = (X_val,y_val),verbose=1)

# Summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Printing mean
means = grid_result.cv_results_['mean_test_score']
# Printing standard deviation
stds = grid_result.cv_results_['std_test_score']
# Printing best parameters
params = grid_result.cv_results_['params']
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 160/160 [==============================] - 1s 2ms/step - loss: 0.4542 - accuracy: 0.8017 - val_loss: 0.4312 - val_accuracy: 0.8056
# Best: 0.815781 using {'batch_size': 40, 'lr': 0.01}

# %% [markdown]
# **Final Model**

# %%
# Creating the model
estimator_v2=create_model_v2(lr=grid_result.best_params_['lr'])
# Printing model summary
estimator_v2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                768
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_h=estimator_v2.fit(X_train, y_train, epochs=100, batch_size = grid_result.best_params_['batch_size'], verbose=1,validation_data=(X_val,y_val))
# Out:
# Epoch 1/100
# 160/160 [==============================] - 1s 2ms/step - loss: 0.4538 - accuracy: 0.8000 - val_loss: 0.4319 - val_accuracy: 0.8188
# Epoch 2/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4285 - accuracy: 0.8200 - val_loss: 0.4148 - val_accuracy: 0.8288
# Epoch 3/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4159 - accuracy: 0.8278 - val_loss: 0.4085 - val_accuracy: 0.8300
# Epoch 4/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4098 - accuracy: 0.8306 - val_loss: 0.4054 - val_accuracy: 0.8381
# Epoch 5/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4025 - accuracy: 0.8323 - val_loss: 0.3966 - val_accuracy: 0.8319
# Epoch 6/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3989 - accuracy: 0.8347 - val_loss: 0.3908 - val_accuracy: 0.8356
# Epoch 7/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3878 - accuracy: 0.8408 - val_loss: 0.3694 - val_accuracy: 0.8438
# Epoch 8/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8439 - val_loss: 0.3713 - val_accuracy: 0.8413
# Epoch 9/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3813 - accuracy: 0.8448 - val_loss: 0.3720 - val_accuracy: 0.8487
# Epoch 10/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3793 - accuracy: 0.8416 - val_loss: 0.3611 - val_accuracy: 0.8481
# Epoch 11/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3689 - accuracy: 0.8475 - val_loss: 0.3617 - val_accuracy: 0.8631
# Epoch 12/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3747 - accuracy: 0.8453 - val_loss: 0.3581 - val_accuracy: 0.8525
# Epoch 13/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3701 - accuracy: 0.8500 - val_loss: 0.3634 - val_accuracy: 0.8444
# Epoch 14/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3693 - accuracy: 0.8481 - val_loss: 0.3559 - val_accuracy: 0.8494
# Epoch 15/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8500 - val_loss: 0.3518 - val_accuracy: 0.8512
# Epoch 16/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8512 - val_loss: 0.3568 - val_accuracy: 0.8475
# Epoch 17/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3621 - accuracy: 0.8536 - val_loss: 0.3639 - val_accuracy: 0.8512
# Epoch 18/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3593 - accuracy: 0.8494 - val_loss: 0.3530 - val_accuracy: 0.8531
# Epoch 19/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3623 - accuracy: 0.8517 - val_loss: 0.3619 - val_accuracy: 0.8512
# Epoch 20/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3580 - accuracy: 0.8530 - val_loss: 0.3597 - val_accuracy: 0.8556
# Epoch 21/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8534 - val_loss: 0.3603 - val_accuracy: 0.8525
# Epoch 22/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3565 - accuracy: 0.8573 - val_loss: 0.3513 - val_accuracy: 0.8556
# Epoch 23/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3578 - accuracy: 0.8550 - val_loss: 0.3507 - val_accuracy: 0.8537
# Epoch 24/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.8547 - val_loss: 0.3516 - val_accuracy: 0.8506
# Epoch 25/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3581 - accuracy: 0.8530 - val_loss: 0.3537 - val_accuracy: 0.8525
# Epoch 26/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3519 - accuracy: 0.8539 - val_loss: 0.3539 - val_accuracy: 0.8525
# Epoch 27/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3523 - accuracy: 0.8527 - val_loss: 0.3633 - val_accuracy: 0.8500
# Epoch 28/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3481 - accuracy: 0.8550 - val_loss: 0.3596 - val_accuracy: 0.8500
# Epoch 29/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3532 - accuracy: 0.8555 - val_loss: 0.3549 - val_accuracy: 0.8544
# Epoch 30/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8561 - val_loss: 0.3587 - val_accuracy: 0.8544
# Epoch 31/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8572 - val_loss: 0.3592 - val_accuracy: 0.8481
# Epoch 32/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3476 - accuracy: 0.8572 - val_loss: 0.3565 - val_accuracy: 0.8550
# Epoch 33/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3465 - accuracy: 0.8581 - val_loss: 0.3548 - val_accuracy: 0.8519
# Epoch 34/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3485 - accuracy: 0.8570 - val_loss: 0.3574 - val_accuracy: 0.8494
# Epoch 35/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.8581 - val_loss: 0.3549 - val_accuracy: 0.8537
# Epoch 36/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3474 - accuracy: 0.8586 - val_loss: 0.3608 - val_accuracy: 0.8525
# Epoch 37/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8562 - val_loss: 0.3510 - val_accuracy: 0.8531
# Epoch 38/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8597 - val_loss: 0.3461 - val_accuracy: 0.8556
# Epoch 39/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3482 - accuracy: 0.8586 - val_loss: 0.3571 - val_accuracy: 0.8556
# Epoch 40/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3452 - accuracy: 0.8608 - val_loss: 0.3558 - val_accuracy: 0.8556
# Epoch 41/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3497 - accuracy: 0.8572 - val_loss: 0.3580 - val_accuracy: 0.8525
# Epoch 42/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.8591 - val_loss: 0.3616 - val_accuracy: 0.8544
# Epoch 43/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.8581 - val_loss: 0.3581 - val_accuracy: 0.8506
# Epoch 44/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.8587 - val_loss: 0.3490 - val_accuracy: 0.8525
# Epoch 45/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3438 - accuracy: 0.8617 - val_loss: 0.3500 - val_accuracy: 0.8562
# Epoch 46/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3480 - accuracy: 0.8603 - val_loss: 0.3569 - val_accuracy: 0.8587
# Epoch 47/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3479 - accuracy: 0.8578 - val_loss: 0.3568 - val_accuracy: 0.8537
# Epoch 48/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3438 - accuracy: 0.8586 - val_loss: 0.3546 - val_accuracy: 0.8606
# Epoch 49/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3466 - accuracy: 0.8600 - val_loss: 0.3582 - val_accuracy: 0.8544
# Epoch 50/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3423 - accuracy: 0.8569 - val_loss: 0.3514 - val_accuracy: 0.8556
# Epoch 51/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3429 - accuracy: 0.8575 - val_loss: 0.3570 - val_accuracy: 0.8487
# Epoch 52/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.8614 - val_loss: 0.3503 - val_accuracy: 0.8625
# Epoch 53/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3372 - accuracy: 0.8592 - val_loss: 0.3569 - val_accuracy: 0.8544
# Epoch 54/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3412 - accuracy: 0.8555 - val_loss: 0.3594 - val_accuracy: 0.8519
# Epoch 55/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3391 - accuracy: 0.8608 - val_loss: 0.3624 - val_accuracy: 0.8512
# Epoch 56/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3419 - accuracy: 0.8619 - val_loss: 0.3536 - val_accuracy: 0.8587
# Epoch 57/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3451 - accuracy: 0.8602 - val_loss: 0.3645 - val_accuracy: 0.8537
# Epoch 58/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3432 - accuracy: 0.8623 - val_loss: 0.3599 - val_accuracy: 0.8531
# Epoch 59/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3439 - accuracy: 0.8578 - val_loss: 0.3548 - val_accuracy: 0.8556
# Epoch 60/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8583 - val_loss: 0.3762 - val_accuracy: 0.8450
# Epoch 61/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3462 - accuracy: 0.8572 - val_loss: 0.3595 - val_accuracy: 0.8512
# Epoch 62/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3378 - accuracy: 0.8605 - val_loss: 0.3599 - val_accuracy: 0.8512
# Epoch 63/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3426 - accuracy: 0.8584 - val_loss: 0.3607 - val_accuracy: 0.8550
# Epoch 64/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.8578 - val_loss: 0.3654 - val_accuracy: 0.8531
# Epoch 65/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3424 - accuracy: 0.8603 - val_loss: 0.3623 - val_accuracy: 0.8512
# Epoch 66/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3420 - accuracy: 0.8602 - val_loss: 0.3532 - val_accuracy: 0.8575
# Epoch 67/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3371 - accuracy: 0.8605 - val_loss: 0.3576 - val_accuracy: 0.8531
# Epoch 68/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3340 - accuracy: 0.8633 - val_loss: 0.3610 - val_accuracy: 0.8469
# Epoch 69/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3396 - accuracy: 0.8577 - val_loss: 0.3606 - val_accuracy: 0.8475
# Epoch 70/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3388 - accuracy: 0.8623 - val_loss: 0.3652 - val_accuracy: 0.8525
# Epoch 71/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3452 - accuracy: 0.8587 - val_loss: 0.3623 - val_accuracy: 0.8481
# Epoch 72/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3413 - accuracy: 0.8562 - val_loss: 0.3607 - val_accuracy: 0.8506
# Epoch 73/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8614 - val_loss: 0.3653 - val_accuracy: 0.8487
# Epoch 74/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8591 - val_loss: 0.3580 - val_accuracy: 0.8462
# Epoch 75/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3329 - accuracy: 0.8631 - val_loss: 0.3623 - val_accuracy: 0.8525
# Epoch 76/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8561 - val_loss: 0.3635 - val_accuracy: 0.8487
# Epoch 77/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3407 - accuracy: 0.8586 - val_loss: 0.3595 - val_accuracy: 0.8525
# Epoch 78/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3427 - accuracy: 0.8614 - val_loss: 0.3613 - val_accuracy: 0.8544
# Epoch 79/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8637 - val_loss: 0.3672 - val_accuracy: 0.8537
# Epoch 80/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3342 - accuracy: 0.8623 - val_loss: 0.3674 - val_accuracy: 0.8487
# Epoch 81/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8575 - val_loss: 0.3685 - val_accuracy: 0.8481
# Epoch 82/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3404 - accuracy: 0.8612 - val_loss: 0.3610 - val_accuracy: 0.8512
# Epoch 83/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3386 - accuracy: 0.8598 - val_loss: 0.3591 - val_accuracy: 0.8494
# Epoch 84/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3383 - accuracy: 0.8586 - val_loss: 0.3660 - val_accuracy: 0.8512
# Epoch 85/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3353 - accuracy: 0.8609 - val_loss: 0.3617 - val_accuracy: 0.8562
# Epoch 86/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.8612 - val_loss: 0.3577 - val_accuracy: 0.8556
# Epoch 87/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8597 - val_loss: 0.3605 - val_accuracy: 0.8550
# Epoch 88/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3359 - accuracy: 0.8631 - val_loss: 0.3608 - val_accuracy: 0.8481
# Epoch 89/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3440 - accuracy: 0.8587 - val_loss: 0.3676 - val_accuracy: 0.8425
# Epoch 90/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8616 - val_loss: 0.3610 - val_accuracy: 0.8544
# Epoch 91/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3375 - accuracy: 0.8623 - val_loss: 0.3708 - val_accuracy: 0.8462
# Epoch 92/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3400 - accuracy: 0.8612 - val_loss: 0.3587 - val_accuracy: 0.8569
# Epoch 93/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3369 - accuracy: 0.8609 - val_loss: 0.3586 - val_accuracy: 0.8525
# Epoch 94/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3392 - accuracy: 0.8603 - val_loss: 0.3607 - val_accuracy: 0.8487
# Epoch 95/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3343 - accuracy: 0.8645 - val_loss: 0.3616 - val_accuracy: 0.8512
# Epoch 96/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3397 - accuracy: 0.8591 - val_loss: 0.3612 - val_accuracy: 0.8494
# Epoch 97/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.3366 - accuracy: 0.8603 - val_loss: 0.3617 - val_accuracy: 0.8450
# Epoch 98/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3339 - accuracy: 0.8645 - val_loss: 0.3656 - val_accuracy: 0.8512
# Epoch 99/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3427 - accuracy: 0.8598 - val_loss: 0.3611 - val_accuracy: 0.8531
# Epoch 100/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.3363 - accuracy: 0.8606 - val_loss: 0.3614 - val_accuracy: 0.8531

# %% [markdown]
# **Loss function**

# %%
N =100
plt.figure(figsize=(8,6))
plt.plot(np.arange(0, N), history_h.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history_h.history["val_loss"], label="val_loss")

plt.title("Training Loss and Validation loss on the dataset")
plt.xlabel("Epoch #")
plt.ylabel("train_Loss/val_loss")
plt.legend(loc="center")
plt.show()

# %% [markdown]
# **Threshold**

# %%
# predict probabilities
yhat = estimator_v2.predict(X_train)
# keep probabilities for the positive outcome only
yhat = yhat[:, 0]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_train, yhat)
# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 200/200 [==============================] - 0s 778us/step
# Best Threshold=0.214415, G-Mean=0.797

# %%
y_pred_h = estimator_v2.predict(X_val)
print(y_pred_h)
# Out:
# 50/50 [==============================] - 0s 780us/step
# [[0.18278202]
#  [0.00351325]
#  [0.0501899 ]
#  ...
#  [0.21441494]
#  [0.55320257]
#  [0.43551806]]

# %%
# Using the best cutoff value to indicate whether customers are likely to exit or not.
y_pred_h = (y_pred_h > thresholds[ix])
print(y_pred_h)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [ True]
#  [ True]]

# %%
cr=metrics.classification_report(y_val,y_pred_h)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      1274
#            1       0.53      0.69      0.60       326
#
#     accuracy                           0.81      1600
#    macro avg       0.72      0.77      0.74      1600
# weighted avg       0.84      0.81      0.82      1600

# %%
cm_h=confusion_matrix(y_val, y_pred_h)

labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm_h,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %% [markdown]
# ### Model Improvement: Neural Network model with balanced data

# %%
sm  = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train.shape))
# Out:
# After UpSampling, the shape of train_X: (10192, 11)
# After UpSampling, the shape of train_y: (10192, 1)

# %%
sns.countplot(y_train['Exited'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Model with balanced dataset**

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
model_4 = Sequential()


model_4.add(Dense(32,activation='relu',input_dim = X_train.shape[1]))


model_4.add(Dropout(0.2))
# Adding hidden layer with 16 neurons with relu as activation function
model_4.add(Dense(16,activation='relu'))

# Adding the dropout
model_4.add(Dropout(0.1))


model_4.add(Dense(8,activation='relu'))


model_4.add(Dense(1, activation = 'sigmoid'))

# %%
model_4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                384
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 8)                 136
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,057
# Trainable params: 1,057
# Non-trainable params: 0
# _________________________________________________________________

# %%
es_cb = callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5)

# Initializing Adam optimizer
optimizer = tf.keras.optimizers.Adam(0.001)

# Complining the model with binary cross entropy as loss and accuracy as metrics
model_4.compile(optimizer = optimizer,loss = 'binary_crossentropy', metrics = ['accuracy'])


history_4 = model_4.fit(X_train,y_train,batch_size=64,epochs=100,verbose=1,validation_data = (X_val,y_val),callbacks=[es_cb])
# Out:
# Epoch 1/100
# 160/160 [==============================] - 1s 2ms/step - loss: 0.6169 - accuracy: 0.6738 - val_loss: 0.5560 - val_accuracy: 0.7362
# Epoch 2/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.5613 - accuracy: 0.7175 - val_loss: 0.5334 - val_accuracy: 0.7331
# Epoch 3/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.5473 - accuracy: 0.7275 - val_loss: 0.5090 - val_accuracy: 0.7481
# Epoch 4/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.7376 - val_loss: 0.5318 - val_accuracy: 0.7325
# Epoch 5/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.5212 - accuracy: 0.7494 - val_loss: 0.5236 - val_accuracy: 0.7431
# Epoch 6/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.5149 - accuracy: 0.7484 - val_loss: 0.5130 - val_accuracy: 0.7531
# Epoch 7/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.5052 - accuracy: 0.7565 - val_loss: 0.5049 - val_accuracy: 0.7538
# Epoch 8/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4996 - accuracy: 0.7607 - val_loss: 0.4785 - val_accuracy: 0.7769
# Epoch 9/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4948 - accuracy: 0.7624 - val_loss: 0.5205 - val_accuracy: 0.7513
# Epoch 10/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4917 - accuracy: 0.7678 - val_loss: 0.4867 - val_accuracy: 0.7681
# Epoch 11/100
# 160/160 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7727 - val_loss: 0.5003 - val_accuracy: 0.7594
# Epoch 12/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4821 - accuracy: 0.7734 - val_loss: 0.4991 - val_accuracy: 0.7563
# Epoch 13/100
# 160/160 [==============================] - 0s 1ms/step - loss: 0.4807 - accuracy: 0.7746 - val_loss: 0.4875 - val_accuracy: 0.7619

# %%
# Capturing learning history per epoch
hist  = pd.DataFrame(history_4.history)
hist['epoch'] = history_4.epoch

# Plotting accuracy at different epochs
plt.plot(hist['loss'])
plt.plot(hist['val_loss'])
plt.legend(("train" , "valid") , loc =0)

# %%
yhat = model_4.predict(X_train)

# keep probabilities for the positive outcome only
yhat = yhat[:, 0]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_train, yhat)
# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 319/319 [==============================] - 0s 725us/step
# Best Threshold=0.486954, G-Mean=0.795

# %%
y_pred_s = model_4.predict(X_val)
#Predicting the results using tuned threshold
y_pred_s = (y_pred_s >thresholds[ix])
y_pred_s
# Out:
# 50/50 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %% [markdown]
# **Classification report**

# %%
cr=metrics.classification_report(y_val,y_pred_s)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.78      0.84      1274
#            1       0.44      0.66      0.53       326
#
#     accuracy                           0.76      1600
#    macro avg       0.67      0.72      0.68      1600
# weighted avg       0.81      0.76      0.77      1600

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
cm_s=confusion_matrix(y_val, y_pred_s)
labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm_s,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %% [markdown]
# ## Final Model

# %%
# predict probabilities using the best model
yhat = model_e.predict(X_train)
# keep probabilities for the positive outcome only
yhat = yhat[:, 0]
# calculate roc curves
fpr, tpr, thresholds = roc_curve(y_train, yhat)
# calculate the g-mean for each threshold
gmeans = np.sqrt(tpr * (1-fpr))
# locate the index of the largest g-mean
ix = np.argmax(gmeans)
print('Best Threshold=%f, G-Mean=%.3f' % (thresholds[ix], gmeans[ix]))
# plot the roc curve for the model
pyplot.plot([0,1], [0,1], linestyle='--', label='No Skill')
pyplot.plot(fpr, tpr, marker='.', label='Logistic')
pyplot.scatter(fpr[ix], tpr[ix], marker='o', color='black', label='Best')
# axis labels
pyplot.xlabel('False Positive Rate')
pyplot.ylabel('True Positive Rate')
pyplot.legend()
# show the plot
pyplot.show()
# Out:
# 319/319 [==============================] - 2s 4ms/step
# Best Threshold=0.192366, G-Mean=0.825

# %%
y_pred_test = model_e.predict(X_test)
y_pred_test = (y_pred_test > thresholds[ix])
print(y_pred_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# [[False]
#  [False]
#  [False]
#  ...
#  [ True]
#  [False]
#  [False]]

# %% [markdown]
# **Classification report**

# %%
cr=metrics.classification_report(y_test,y_pred_test)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1593
#            1       0.52      0.73      0.61       407
#
#     accuracy                           0.81      2000
#    macro avg       0.72      0.78      0.74      2000
# weighted avg       0.84      0.81      0.82      2000

# %%
cm_h=confusion_matrix(y_test, y_pred_test)
labels = ['True Negative','False Positive','False Negative','True Positive']
categories = [ 'Not_Exited','Exited']
make_confusion_matrix(cm_h,
                      group_names=labels,
                      categories=categories,
                      cmap='Blues')

# %% [markdown]
# ## Actionable Insights and Recommendations

# %% [markdown]
# **What recommedations would you suggest to the bank?**

# %% [markdown]
# * **Recommendations**

# %% [markdown]
# The results of model(s) are quite interesting. Amidst finding optimal thresholds, applying hyperparameter tuning, etc., the goal at the end of the day was to maximize Recall and minimize False Negatives. I believe our final model was able to achieve a high Recall score without sacrificing variables such as Accuracy, Precision, and F1 Score.
#
# After looking back at the univariate and bivariate relationships within the customer data, it seems that the bank has a broad scope of customers of different ages, credit scores, and countries. It is interesting to see the almost 1/3 of customers do not have a credit card. That is one vital way that a bank builds up a relationship with its customers, and one simple way to work incentives into terms to keep people from exiting.
#
# With only 20% of global customers exiting in the actual data, it is very possible to decrease this number by catering more to the customer, especially if their credit score is higher or if they have a higher balance in their account.
#
# Finally, our goal was to mitigate the False Negatives with achieving a higher Recall score. It is reassuring to see that only 6.2% of customers were predicted to Not Exit, but ended up Exiting. Globally, if new data is often added and monitored, it would make this model a reliable way to keep customers in the door or at least better prepare for a possible exit.

# %% [markdown]
# ___
